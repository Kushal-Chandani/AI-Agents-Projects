# %% [markdown]
# ### Part 2: Multi-User Request Simulation

# %%
import requests
import json

def run_simulation():
    """
    Simulates 10 different user queries by sending requests to the FastAPI server.
    """
    api_url = "http://127.0.0.1:8000/query"

    print("--- Starting Multi-User Simulation ---")

    user_queries = [
        "When is the next bus for service 169 arriving at bus stop 58241?",
        "Are there any taxis available right now?",
        "What are the current traffic conditions? Any accidents?",
        "I'm at bus stop 77009. What are the arrival times?",
        "How many taxis are there in total?",
        "Any road work happening on the PIE expressway?",
        "Next bus for service 969 at stop 58009?",
        "Show me all traffic incidents.",
        "How crowded is the next bus for service 36 at bus stop 95009?",
        "Are there any accidents near Orchard Road?",
    ]

    for i, query in enumerate(user_queries):
        print(f"\n--- Query {i+1}: \"{query}\" ---")

        try:
            response = requests.post(api_url, json={"query": query})
            response.raise_for_status()

            data = response.json()
            agent_response = data.get("response", "No response found.")

            print(f"Agent Response: {agent_response}")

        except requests.exceptions.RequestException as e:
            print(f"Error querying the agent: {e}")
        except json.JSONDecodeError:
            print("Error: Could not decode JSON response from the server.")

    print("\n--- Simulation Complete ---")

if __name__ == "__main__":
    run_simulation()
# Out:
# --- Starting Multi-User Simulation ---
#
# --- Query 1: "When is the next bus for service 169 arriving at bus stop 58241?" ---
# Agent Response: There is no bus service 169 at bus stop 58241.
#
# --- Query 2: "Are there any taxis available right now?" ---
# Agent Response: Yes, there are many taxis available right now. I found 400 taxis.
#
# --- Query 3: "What are the current traffic conditions? Any accidents?" ---
# Agent Response: There is currently one accident: (6/9)17:22 Accident in KPE Tunnel (towards ECP) at Pan Island Expressway Entrance.
#
# There are also various roadworks, vehicle breakdowns, and heavy traffic reported.
#
# --- Query 4: "I'm at bus stop 77009. What are the arrival times?" ---
# Agent Response: Here are the bus arrival times for bus stop 77009:
#
# *   **Service 12**:
#     *   17:31 (Double Deck, Standing Available)
#     *   17:46 (Double Deck, Standing Available)
#     *   18:01 (Single Deck, Standing Available)
# *   **Service 12e**:
#     *   17:30 (Double Deck, Standing Available)
#     *   18:00 (Double Deck, Standing Available)
# *   **Service 15**:
#     *   17:31 (Single Deck, Standing Available)
#     *   18:02 (Single Deck, Standing Available)
# *   **Service 17**:
#     *   17:37 (Single Deck, Standing Available)
#     *   17:51 (Double Deck, Standing Available)
#     *   18:05 (Double Deck, Standing Available)
# *   **Service 21**:
#     *   17:32 (Double Deck, Standing Available)
#     *   17:48 (Single Deck, Standing Available)
#     *   18:04 (Double Deck, Standing Available)
# *   **Service 3**:
#     *   17:34 (Single Deck, Standing Available)
#     *   17:51 (Single Deck, Standing Available)
# *   **Service 354**:
#     *   17:36 (Single Deck, Standing Available)
#     *   17:49 (Single Deck, Standing Available)
#     *   18:02 (Single Deck, Standing Available)
# *   **Service 358**:
#     *   17:30 (Single Deck, Standing Available)
#     *   17:37 (Single Deck, Standing Available)
#     *   17:42 (Single Deck, Standing Available)
# *   **Service 359**:
#     *   17:32 (Single Deck, Standing Available)
#     *   17:38 (Single Deck, Standing Available)
#     *   17:43 (Single Deck, Standing Available)
# *   **Service 403**:
#     *   17:45 (Single Deck, Standing Available)
#     *   18:00 (Single Deck, Standing Available)
# *   **Service 46**:
#     *   17:29 (Double Deck, Standing Available)
#     *   17:44 (Double Deck, Standing Available)
#     *   17:59 (Double Deck, Standing Available)
# *   **Service 5**:
#     *   17:36 (Double Deck, Standing Available)
#     *   17:52 (Single Deck, Standing Available)
#     *   18:09 (Double Deck, Standing Available)
# *   **Service 518**:
#     *   17:33 (Double Deck, Standing Available)
#     *   17:53 (Double Deck, Standing Available)
# *   **Service 58**:
#     *   17:36 (Double Deck, Standing Available)
#     *   17:54 (Double Deck, Standing Available)
#     *   18:11 (Single Deck, Standing Available)
# *   **Service 68**:
#     *   17:42 (Double Deck, Standing Available)
#     *   17:54 (Double Deck, Standing Available)
#     *   18:06 (Double Deck, Standing Available)
# *   **Service 88**:
#     *   17:32 (Double Deck, Standing Available)
#     *   17:46 (Double Deck, Standing Available)
#     *   18:03 (Double Deck, Standing Available)
#
# --- Query 5: "How many taxis are there in total?" ---
# Agent Response: There are 300 taxis available.
#
# --- Query 6: "Any road work happening on the PIE expressway?" ---
# Agent Response: Yes, there are a few road works happening on the PIE expressway:
#
# * (6/9)14:59 Road Works on PIE (towards Changi) at TPE Exit.
# * (6/9)14:52 Road Works on PIE (towards Tuas) before Jurong West Ave 2. Avoid lane 3.
# * (6/9)14:32 Road Works on PIE (towards Tuas) before Pioneer Rd North. Avoid lane 4.
# * (6/9)14:24 Road Works on PIE (towards Changi) at Jurong West Avenue 2 Entrance.
#
# --- Query 7: "Next bus for service 969 at stop 58009?" ---
# Agent Response: There is no bus service 969 at bus stop 58009.
#
# --- Query 8: "Show me all traffic incidents." ---
# Agent Response: Here are the traffic incidents:
# - Vehicle breakdown on AYE (towards Tuas) before Telok Blangah Rd.
# - Accident in KPE Tunnel (towards ECP) at Pan Island Expressway Entrance.
# - Vehicle breakdown on AYE (towards MCE) before Jurong Town Hall Rd. Avoid lane 4.
# - Road Works on Xilin Avenue (towards ECP) before ECP. Avoid lanes 2 and 3.
# - Road Works on AYE (towards MCE) at Jurong Town Hall Road Entrance.
# - Heavy Traffic on Bukit Timah Road (towards City) between Serangoon Road and CTE.
# - Road Works on TPE (towards SLE) at Loyang Ave Exit.
# - Road Works on TPE (towards SLE) at Loyang Avenue Entrance.
# - Road Works on AYE (towards Tuas) before Tuas West Rd. Avoid lane 3.
# - Road Works on PIE (towards Changi) at TPE Exit.
# - Road Works on PIE (towards Tuas) before Jurong West Ave 2. Avoid lane 3.
# - Road Works on TPE (towards PIE) before Pasir Ris Drive 8. Avoid lane 3.
# - Heavy Traffic on PIE (towards Changi) at KPE(ECP) Exit.
# - Road Works on AYE (towards Tuas) before Pioneer Rd. Avoid lane 1.
# - Road Works on TPE (towards SLE) before Tampines Rd. Avoid lane 3.
# - Road Works on TPE (towards SLE) at Seletar Link Entrance.
# - Road Works on AYE (towards Tuas) before Clementi Rd. Avoid lane 4.
# - Road Works on KJE (towards BKE) before Sungei Tengah. Avoid lane 1.
# - Road Works on BKE (towards PIE) before PIE(City).
# - Road Works on PIE (towards Tuas) before Pioneer Rd North. Avoid lane 4.
# - Road Works on KJE (towards PIE) before Choa Chu Kang Drive. Avoid lane 3.
# - Road Works on Kallang Paya Lebar Expressway (towards TPE) before Tampines Rd.
# - Heavy Traffic on BKE (towards W'lands) at Woodlands Rd Exit.
# - Road Works on PIE (towards Changi) at Jurong West Avenue 2 Entrance.
# - Road Works on ECP (towards City) at Bedok South Ave 1 Exit.
# - Road Works on AYE (towards Tuas) before Jurong Town Hall Rd.
# - Road Closure on Serangoon Road (towards Sengkang) before Buffalo Road. Serangoon Road closed after Bukit Timah Road.
#
# --- Query 9: "How crowded is the next bus for service 36 at bus stop 95009?" ---
# Agent Response: I am sorry, I cannot provide information about the crowding level of the bus as the available tools do not support this functionality. I can only fetch real-time bus arrival times.
#
# --- Query 10: "Are there any accidents near Orchard Road?" ---
# Agent Response: There are no accidents reported near Orchard Road. There is an accident reported in KPE Tunnel (towards ECP) at Pan Island Expressway Entrance.
#
# --- Simulation Complete ---
